# %%
from lxml import html, etree

# %%
import requests

# %%
import pandas as pd

# %%
import fastparquet

# %%
import numpy as np

# %%
page = requests.get('https://www.gov.uk/government/publications/register-of-licensed-sponsors-workers')
tree = html.fromstring(page.content)

# %%
download_path = tree.xpath('//*[@id="attachment_4271537"]/div[2]/h2/a')[0].get("href")

# %%
print(download_path)
# Out:
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/891847/2020-06-12_Tier_2_5_Register_of_Sponsors.pdf

# %%
response = requests.get(download_path)

# %%
with open('/tmp/metadata.pdf', 'wb') as f:
    f.write(response.content)

# %%
# python3 pdf2txt.py metadata.pdf --output_type xml  --outfile raw.xml

# %%
# python3 pdf2txt.py metadata.pdf --output_type html  --outfile raw.html

# %%
# with open('./raw-sample.html', 'r') as f:
#     page = f.read()
# doc = html.fromstring(page)

# %%
with open('./raw_html_all.html', 'r') as f:
    page = f.read()
doc = html.fromstring(page)

# %%
doc.xpath('/html/body/div[7]')[0].text

# %% [markdown]
# ## Extract Organisation Name

# %%
name = []

isFirst = False

for col in doc.xpath("//div/span"):
    if ("left:30px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
            pairs = {'style': p_style, 'name': col.text.strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            if (df_city_sorted[ (df_city_sorted['top'] - pairs['top']).abs() < 10 ].shape[0]) == 1:
                pairs['city_top'] = (df_city_sorted[ (df_city_sorted['top'] - pairs['top']).abs() < 10 ].iloc[0]['top'])
            name.append(pairs)
            isFirst = True
#             break

df_name = pd.DataFrame(name)
df_name_sorted = df_name.sort_values(by=['top'])
# df_name_sorted[0:]

# %%
df_name_sorted
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height  \
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
#         city_top
# 0          266.0
# 1          309.0
# 2          339.0
# 3          370.0
# 4          400.0
# ...          ...
# 31314  1330348.0
# 31315  1330391.0
# 31316  1330422.0
# 31322  1330465.0
# 31323  1330495.0
#
# [31324 rows x 7 columns]

# %%
df_name_sorted[df_name_sorted['city_top'].isnull() ]
# Out:
#                                                    style  \
# 1288   position:absolute; border: textbox 1px solid; ...
# 1289   position:absolute; border: textbox 1px solid; ...
# 5049   position:absolute; border: textbox 1px solid; ...
# 5048   position:absolute; border: textbox 1px solid; ...
# 5610   position:absolute; border: textbox 1px solid; ...
# 5611   position:absolute; border: textbox 1px solid; ...
# 7083   position:absolute; border: textbox 1px solid; ...
# 7082   position:absolute; border: textbox 1px solid; ...
# 8549   position:absolute; border: textbox 1px solid; ...
# 8548   position:absolute; border: textbox 1px solid; ...
# 10811  position:absolute; border: textbox 1px solid; ...
# 10812  position:absolute; border: textbox 1px solid; ...
# 13567  position:absolute; border: textbox 1px solid; ...
# 13566  position:absolute; border: textbox 1px solid; ...
# 14446  position:absolute; border: textbox 1px solid; ...
# 14447  position:absolute; border: textbox 1px solid; ...
# 18640  position:absolute; border: textbox 1px solid; ...
# 18641  position:absolute; border: textbox 1px solid; ...
# 20572  position:absolute; border: textbox 1px solid; ...
# 20573  position:absolute; border: textbox 1px solid; ...
# 21416  position:absolute; border: textbox 1px solid; ...
# 21417  position:absolute; border: textbox 1px solid; ...
# 22441  position:absolute; border: textbox 1px solid; ...
# 22442  position:absolute; border: textbox 1px solid; ...
# 22443  position:absolute; border: textbox 1px solid; ...
# 22444  position:absolute; border: textbox 1px solid; ...
# 24898  position:absolute; border: textbox 1px solid; ...
# 24897  position:absolute; border: textbox 1px solid; ...
# 26972  position:absolute; border: textbox 1px solid; ...
# 26973  position:absolute; border: textbox 1px solid; ...
# 27184  position:absolute; border: textbox 1px solid; ...
# 27185  position:absolute; border: textbox 1px solid; ...
# 27438  position:absolute; border: textbox 1px solid; ...
# 27439  position:absolute; border: textbox 1px solid; ...
# 27569  position:absolute; border: textbox 1px solid; ...
# 27570  position:absolute; border: textbox 1px solid; ...
# 27696  position:absolute; border: textbox 1px solid; ...
# 27697  position:absolute; border: textbox 1px solid; ...
# 27700  position:absolute; border: textbox 1px solid; ...
# 27701  position:absolute; border: textbox 1px solid; ...
# 27891  position:absolute; border: textbox 1px solid; ...
# 27892  position:absolute; border: textbox 1px solid; ...
# 30067  position:absolute; border: textbox 1px solid; ...
# 30066  position:absolute; border: textbox 1px solid; ...
#
#                                                     name  left      top  \
# 1288   AL-QUDS AL-ARABI PUBLISHING AND ADVERTISING (O...    30    54489
# 1289                                              London    30    54489
# 5049                                              LONDON    30   212611
# 5048   CASPIAN HEALTHCARE LTD T/A (WATERFALL HOUSE DE...    30   212611
# 5610                                              London    30   235838
# 5611   China Council for the Promotion of Internation...    30   235838
# 7083                                 NEWCASTLE UPON TYNE    30   299158
# 7082   CUMBRIA, NORTHUMBERLAND, TYNE AND WEAR NHS FOU...    30   299158
# 8549                                             Edgware    30   361484
# 8548   EDGWARE ACCOUNTANTS & TAX ADVISORS LTD T/As Ed...    30   361484
# 10811  GCS Compliance Services Europe Unlimited Compa...    30   457767
# 10812                                          Brentford    30   457767
# 13567                                             London    30   575206
# 13566  Inn on the Park (London) Limited doing busines...    30   575206
# 14446  JESUS CARES CRUSADERS MINISTRIES INTERNATIONAL...    30   613200
# 14447                                             LONDON    30   613200
# 18640  NASRUL-LAHI-L-FAITH SOCIETY OF NIGERIA (MANCHE...    30   790679
# 18641                                         MANCHESTER    30   790679
# 20572                                             London    30   873101
# 20573  Paul, Weiss, Rifkind, Wharton & Garrison LLP, ...    30   873101
# 21416  Premier Marketing and Distribution Ltd trading...    30   908309
# 21417                                             London    30   908309
# 22441                                              Rugby    30   951463
# 22442  REDEEMED CHRISTIAN CHURCH OF GOD (RCCG) HARVES...    30   951463
# 22443  Redeemed Christian Church of God Covenant Rest...    30   951493
# 22444                                         Birmingham    30   951493
# 24898  Society of Catholic Medical Missionaries Centr...    30  1056131
# 24897                                              Acton    30  1056131
# 26972  The Association of Independent Professionals a...    30  1144397
# 26973                                             London    30  1144397
# 27184  The Corporation of the Hall of Arts and Scienc...    30  1153009
# 27185                                             London    30  1153009
# 27438  THE INTERNATIONAL SCHOOL OF ABERDEEN EDUCATION...    30  1163975
# 27439                                           ABERDEEN    30  1163975
# 27569  The Master and Fellows of Emmanuel College in ...    30  1169595
# 27570                                          Cambridge    30  1169595
# 27696  The Parochial Church Council of the Ecclesiast...    30  1175033
# 27697                                             London    30  1175033
# 27700  The Parochial Church Council of the Ecclesiast...    30  1175278
# 27701                                        Walthamstow    30  1175278
# 27891                                            Enfield    30  1183663
# 27892  THE SISTERS OF THE HOLY FAMILY OF NAZARETH ( G...    30  1183663
# 30067                                           Aberdeen    30  1277010
# 30066  WATCHMAN CATHOLIC CHARISMATIC RENEWAL MOVEMENT...    30  1277010
#
#        width  height  city_top
# 1288     356       9       NaN
# 1289     356       9       NaN
# 5049     365       9       NaN
# 5048     365       9       NaN
# 5610     359       9       NaN
# 5611     359       9       NaN
# 7083     437       9       NaN
# 7082     437       9       NaN
# 8549     362       9       NaN
# 8548     362       9       NaN
# 10811    363       9       NaN
# 10812    363       9       NaN
# 13567    356       9       NaN
# 13566    356       9       NaN
# 14446    365       9       NaN
# 14447    365       9       NaN
# 18640    389       9       NaN
# 18641    389       9       NaN
# 20572    356       9       NaN
# 20573    356       9       NaN
# 21416    356       9       NaN
# 21417    356       9       NaN
# 22441    354       9       NaN
# 22442    354       9       NaN
# 22443    374       9       NaN
# 22444    374       9       NaN
# 24898    349       9       NaN
# 24897    349       9       NaN
# 26972    356       9       NaN
# 26973    356       9       NaN
# 27184    356       9       NaN
# 27185    356       9       NaN
# 27438    376       9       NaN
# 27439    376       9       NaN
# 27569    370       9       NaN
# 27570    370       9       NaN
# 27696    356       9       NaN
# 27697    356       9       NaN
# 27700    380       9       NaN
# 27701    380       9       NaN
# 27891    355       9       NaN
# 27892    355       9       NaN
# 30067    365       9       NaN
# 30066    365       9       NaN

# %% [markdown]
# ## Extract Organisation Location

# %%
city = []
for col in doc.xpath("//div/span"):
    if ("left:357px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
            pairs = {'style': p_style, 'name': col.text.strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
#             print(pairs['top'])
            if (df_name_sorted[ (df_name_sorted['top'] - pairs['top']).abs() < 10 ].shape[0]) == 1:
                pairs['name_top'] = (df_name_sorted[ (df_name_sorted['top'] - pairs['top']).abs() < 10 ].iloc[0]['top'])
#             print(pairs)
            city.append(pairs)
            isFirst = True
#             break

# %%
df_city = pd.DataFrame(city)

# %%
df_city_sorted = df_city.sort_values(by=['top'])

# %%
df_city_sorted
# Out:
#                                                    style             name  \
# 0      position:absolute; border: textbox 1px solid; ...           London
# 1      position:absolute; border: textbox 1px solid; ...       Folkestone
# 2      position:absolute; border: textbox 1px solid; ...           London
# 3      position:absolute; border: textbox 1px solid; ...           London
# 4      position:absolute; border: textbox 1px solid; ...           Slough
# ...                                                  ...              ...
# 31275  position:absolute; border: textbox 1px solid; ...        Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...  Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...        Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...           London
# 31279  position:absolute; border: textbox 1px solid; ...           London
#
#        left      top  width  height  name_top
# 0       357      266     29       8       266
# 1       357      309     43       8       309
# 2       357      339     29       8       340
# 3       357      370     29       8       370
# 4       357      400     27       8       401
# ...     ...      ...    ...     ...       ...
# 31275   357  1330348     32       8   1330349
# 31276   357  1330391     67       8   1330392
# 31277   357  1330422     47       8   1330422
# 31278   357  1330465     29       8   1330465
# 31279   357  1330495     29       8   1330496
#
# [31280 rows x 7 columns]

# %%
df_city_sorted[df_city_sorted['name_top'].isnull() ]
# Out:
# Empty DataFrame
# Columns: [style, name, left, top, width, height, name_top]
# Index: []

# %% [markdown]
# ## Extract Tier & Rating

# %%
tier_and_rating = []
for col in doc.xpath("//div/span"):
    if ("left:582px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
#             print(col.text_content().strip())
#             print(etree.tostring(col))
            pairs = {'style': p_style, 'name': col.text_content().strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            tier_and_rating.append(pairs)
            isFirst = True
#             break

# %% [markdown]
# ## Extract Sub Tier

# %%
sub_tier = []
for col in doc.xpath("//div/span"):
    if ("left:684px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
#             print(col.text_content().strip())
#             print(etree.tostring(col))
            pairs = {'style': p_style, 'name': col.text_content().strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            sub_tier.append(pairs)
            isFirst = True
#             break

# %%
len(city)
# Out:
# 31280

# %%
name[101]
# Out:
# {'height': 8,
#  'left': 30,
#  'name': '3HR PLC',
#  'style': 'position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:30px; top:4246px; width:37px; height:8px;',
#  'top': 4246,
#  'width': 37}

# %%
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
# [31324 rows x 6 columns]

# %%
# Out:
#                                                    style                 name  \
# 25     position:absolute; border: textbox 1px solid; ...               Durely
# 26     position:absolute; border: textbox 1px solid; ...  Newcastle upon Tyne
# 21     position:absolute; border: textbox 1px solid; ...             Brighton
# 22     position:absolute; border: textbox 1px solid; ...               LONDON
# 23     position:absolute; border: textbox 1px solid; ...               London
# ...                                                  ...                  ...
# 31275  position:absolute; border: textbox 1px solid; ...            Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...      Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...            Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...               London
# 31279  position:absolute; border: textbox 1px solid; ...               London
#
#        left      top  width  height
# 25      357     1069     25       8
# 26      357     1100     86       8
# 21      357     1130     33       8
# 22      357     1161     38       8
# 23      357     1192     29       8
# ...     ...      ...    ...     ...
# 31275   357  1330348     32       8
# 31276   357  1330391     67       8
# 31277   357  1330422     47       8
# 31278   357  1330465     29       8
# 31279   357  1330495     29       8
#
# [31259 rows x 6 columns]

# %%
df_city_sorted[25:]
# Out:
#                                                    style               name  \
# 23     position:absolute; border: textbox 1px solid; ...             London
# 24     position:absolute; border: textbox 1px solid; ...           Brighton
# 27     position:absolute; border: textbox 1px solid; ...             London
# 28     position:absolute; border: textbox 1px solid; ...  Jewellery quarter
# 29     position:absolute; border: textbox 1px solid; ...             London
# ...                                                  ...                ...
# 31275  position:absolute; border: textbox 1px solid; ...          Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...    Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...          Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...             London
# 31279  position:absolute; border: textbox 1px solid; ...             London
#
#        left      top  width  height
# 23      357     1192     29       8
# 24      357     1222     33       8
# 27      357     1378     29       8
# 28      357     1408     68       8
# 29      357     1439     29       8
# ...     ...      ...    ...     ...
# 31275   357  1330348     32       8
# 31276   357  1330391     67       8
# 31277   357  1330422     47       8
# 31278   357  1330465     29       8
# 31279   357  1330495     29       8
#
# [31255 rows x 6 columns]

# %%
df_name_sorted[25:]
# Out:
#                                                    style  \
# 23     position:absolute; border: textbox 1px solid; ...
# 24     position:absolute; border: textbox 1px solid; ...
# 28     position:absolute; border: textbox 1px solid; ...
# 29     position:absolute; border: textbox 1px solid; ...
# 30     position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                               name  left      top  width  height
# 23             1508 London Limited    30     1192     87       8
# 24                     15GIFTS LTD    30     1223     54       8
# 28              16HarleyCo Limited    30     1378     81       8
# 29                  16printing Ltd    30     1409     58       8
# 30         17 Capital Services Ltd    30     1439     95       8
# ...                            ...   ...      ...    ...     ...
# 31314     Zytek Automotive Limited    30  1330349    106       8
# 31315    Zytronic Displays Limited    30  1330392    106       8
# 31316  ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                     ZZ&D LtD    30  1330465     40       8
# 31323                Zzish Limited    30  1330496     55       8
#
# [31299 rows x 6 columns]

# %%
df_sub_tier = pd.DataFrame(sub_tier)

# %%
df_sub_tier_sorted = df_sub_tier.sort_values(by=['top'])

# %%
df_sub_tier_sorted[0:]
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left      top  width  \
# 0                Tier 2 General\nCreative & Sporting   684      279     77
# 1                                Creative & Sporting   684      322     77
# 2                                     Tier 2 General   684      353     57
# 3                                     Tier 2 General   684      383     57
# 4                                     Tier 2 General   684      414     57
# ...                                              ...   ...      ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362    121
# 32584                                 Tier 2 General   684  1330405     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330435    121
# 32586                                 Tier 2 General   684  1330478     57
# 32587                                 Tier 2 General   684  1330509     57
#
#        height
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]

# %%
df_tier_and_rating = pd.DataFrame(tier_and_rating)

# %%
df_tier_and_rating_sorted = df_tier_and_rating.sort_values(by=['top'])

# %%
df_tier_and_rating_sorted
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32673  position:absolute; border: textbox 1px solid; ...
# 32674  position:absolute; border: textbox 1px solid; ...
# 32675  position:absolute; border: textbox 1px solid; ...
# 32676  position:absolute; border: textbox 1px solid; ...
# 32677  position:absolute; border: textbox 1px solid; ...
#
#                                        name  left      top  width  height
# 0      Tier 2 (A rating)\nTier 5 (A rating)   582      278     62      21
# 1                         Tier 5 (A rating)   582      321     62       8
# 2                         Tier 2 (A rating)   582      351     62       8
# 3                         Tier 2 (A rating)   582      382     62       8
# 4                         Tier 2 (A rating)   582      412     62       8
# ...                                     ...   ...      ...    ...     ...
# 32673  Tier 2 (A rating)\nTier 2 (A rating)   582  1330360     62      21
# 32674                     Tier 2 (A rating)   582  1330403     62       8
# 32675  Tier 2 (A rating)\nTier 2 (A rating)   582  1330434     62      21
# 32676                     Tier 2 (A rating)   582  1330477     62       8
# 32677                     Tier 2 (A rating)   582  1330507     62       8
#
# [32678 rows x 6 columns]

# %%
# for content in contents:
#     text_object = content.getObject()
#     print(text_object)

# %%
# with open("raw_text.csv", "w") as text_file:
#     text_file.write(all_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8f96918366a3> in <module>()
#       1 with open("raw_text.csv", "w") as text_file:
# ----> 2     text_file.write(all_text)
#
# NameError: name 'all_text' is not defined

# %%
# contents = pageObj.getContents()

# %% [markdown]
# ## Export dataframe to parquet

# %%
# pip install fastparquet ( if not already installed )

# %%
df_name_sorted.to_parquet('df_name_sorted.parquet.gzip',
              compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c3dadfb0c74d> in <module>
# ----> 1 df_name_sorted.to_parquet('df_name_sorted.parquet.gzip',
#       2               compression='gzip')
#
# NameError: name 'df_name_sorted' is not defined

# %%
df_city_sorted.to_parquet('df_city_sorted.parquet.gzip',
              compression='gzip')

# %%
df_tier_and_rating_sorted.to_parquet('df_tier_and_rating_sorted.parquet.gzip',
              compression='gzip')

# %%
df_sub_tier_sorted.to_parquet('df_sub_tier_sorted.parquet.gzip',
              compression='gzip')

# %%
df_sub_tier_sorted
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left      top  width  \
# 0                Tier 2 General\nCreative & Sporting   684      279     77
# 1                                Creative & Sporting   684      322     77
# 2                                     Tier 2 General   684      353     57
# 3                                     Tier 2 General   684      383     57
# 4                                     Tier 2 General   684      414     57
# ...                                              ...   ...      ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362    121
# 32584                                 Tier 2 General   684  1330405     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330435    121
# 32586                                 Tier 2 General   684  1330478     57
# 32587                                 Tier 2 General   684  1330509     57
#
#        height
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]

# %% [markdown]
# ## Import dataframe from parquet

# %%
df_name_sorted_imported = pd.read_parquet('df_name_sorted.parquet.gzip')

# %%
df_name_sorted_imported[0:]
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height
# index
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
# [31324 rows x 6 columns]

# %%
# df_name_sorted_imported['top'] = (df_name_sorted_imported['top'] / 2).apply(np.round) * 2

# %%
# df_name_sorted_imported
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left        top  width  height
# index
# 0      @ Home Accommodation Services Ltd    30      266.0    160       8
# 1               ]performance s p a c e [    30      308.0     98       8
# 2                               06472420    30      340.0     38       8
# 3                      0-two Maintenance    30      370.0     78       8
# 4              1 Digitals Europe Limited    30      400.0    105       8
# ...                                  ...   ...        ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330348.0    106       8
# 31315          Zytronic Displays Limited    30  1330392.0    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422.0    131       8
# 31322                           ZZ&D LtD    30  1330464.0     40       8
# 31323                      Zzish Limited    30  1330496.0     55       8
#
# [31324 rows x 6 columns]

# %%
df_city_sorted_imported = pd.read_parquet('df_city_sorted.parquet.gzip')

# %%
df_city_sorted_imported
# Out:
#                                                    style             name  \
# index
# 0      position:absolute; border: textbox 1px solid; ...           London
# 1      position:absolute; border: textbox 1px solid; ...       Folkestone
# 2      position:absolute; border: textbox 1px solid; ...           London
# 3      position:absolute; border: textbox 1px solid; ...           London
# 4      position:absolute; border: textbox 1px solid; ...           Slough
# ...                                                  ...              ...
# 31275  position:absolute; border: textbox 1px solid; ...        Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...  Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...        Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...           London
# 31279  position:absolute; border: textbox 1px solid; ...           London
#
#        left      top  width  height
# index
# 0       357      266     29       8
# 1       357      309     43       8
# 2       357      339     29       8
# 3       357      370     29       8
# 4       357      400     27       8
# ...     ...      ...    ...     ...
# 31275   357  1330348     32       8
# 31276   357  1330391     67       8
# 31277   357  1330422     47       8
# 31278   357  1330465     29       8
# 31279   357  1330495     29       8
#
# [31280 rows x 6 columns]

# %%
# df_city_sorted_imported['top'] = (df_city_sorted_imported['top'] / 2).apply(np.round) * 2

# %%
# df_city_sorted_imported
# Out:
#                                                    style             name  \
# index
# 0      position:absolute; border: textbox 1px solid; ...           London
# 1      position:absolute; border: textbox 1px solid; ...       Folkestone
# 2      position:absolute; border: textbox 1px solid; ...           London
# 3      position:absolute; border: textbox 1px solid; ...           London
# 4      position:absolute; border: textbox 1px solid; ...           Slough
# ...                                                  ...              ...
# 31275  position:absolute; border: textbox 1px solid; ...        Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...  Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...        Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...           London
# 31279  position:absolute; border: textbox 1px solid; ...           London
#
#        left        top  width  height
# index
# 0       357      266.0     29       8
# 1       357      308.0     43       8
# 2       357      340.0     29       8
# 3       357      370.0     29       8
# 4       357      400.0     27       8
# ...     ...        ...    ...     ...
# 31275   357  1330348.0     32       8
# 31276   357  1330392.0     67       8
# 31277   357  1330422.0     47       8
# 31278   357  1330464.0     29       8
# 31279   357  1330496.0     29       8
#
# [31280 rows x 6 columns]

# %%
df_tier_and_rating_sorted_imported = pd.read_parquet('df_tier_and_rating_sorted.parquet.gzip')

# %%
df_tier_and_rating_sorted_imported
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32673  position:absolute; border: textbox 1px solid; ...
# 32674  position:absolute; border: textbox 1px solid; ...
# 32675  position:absolute; border: textbox 1px solid; ...
# 32676  position:absolute; border: textbox 1px solid; ...
# 32677  position:absolute; border: textbox 1px solid; ...
#
#                                        name  left      top  width  height
# index
# 0      Tier 2 (A rating)\nTier 5 (A rating)   582      278     62      21
# 1                         Tier 5 (A rating)   582      321     62       8
# 2                         Tier 2 (A rating)   582      351     62       8
# 3                         Tier 2 (A rating)   582      382     62       8
# 4                         Tier 2 (A rating)   582      412     62       8
# ...                                     ...   ...      ...    ...     ...
# 32673  Tier 2 (A rating)\nTier 2 (A rating)   582  1330360     62      21
# 32674                     Tier 2 (A rating)   582  1330403     62       8
# 32675  Tier 2 (A rating)\nTier 2 (A rating)   582  1330434     62      21
# 32676                     Tier 2 (A rating)   582  1330477     62       8
# 32677                     Tier 2 (A rating)   582  1330507     62       8
#
# [32678 rows x 6 columns]

# %%
df_tier_and_rating_sorted_imported['top'] = df_tier_and_rating_sorted_imported['top']/5

# %%
df_sub_tier_sorted_imported = pd.read_parquet('df_sub_tier_sorted.parquet.gzip')

# %%
df_sub_tier_sorted_imported['top'] = (df_sub_tier_sorted_imported['top'] / 3).apply(np.ceil) * 3

# %%
df_sub_tier_sorted_imported
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left        top  width  \
# index
# 0                Tier 2 General\nCreative & Sporting   684      279.0     77
# 1                                Creative & Sporting   684      324.0     77
# 2                                     Tier 2 General   684      354.0     57
# 3                                     Tier 2 General   684      384.0     57
# 4                                     Tier 2 General   684      414.0     57
# ...                                              ...   ...        ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362.0    121
# 32584                                 Tier 2 General   684  1330407.0     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330437.0    121
# 32586                                 Tier 2 General   684  1330479.0     57
# 32587                                 Tier 2 General   684  1330509.0     57
#
#        height
# index
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]

# %%
df_newdata = df_name_sorted_imported

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-479505d38296> in <module>
# ----> 1 df_city_sorted_imported[0:'city_name'] = "a"
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2924
#    2925         # see if we can slice the rows
# -> 2926         indexer = convert_to_index_sliceable(self, key)
#    2927         if indexer is not None:
#    2928             # either we have a slice or we have a string that can be converted
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2265     idx = obj.index
#    2266     if isinstance(key, slice):
# -> 2267         return idx._convert_slice_indexer(key, kind="getitem")
#    2268
#    2269     elif isinstance(key, str):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in _convert_slice_indexer(self, key, kind)
#    2936                 return slice(
#    2937                     self._validate_indexer("slice", key.start, kind),
# -> 2938                     self._validate_indexer("slice", key.stop, kind),
#    2939                     self._validate_indexer("slice", key.step, kind),
#    2940                 )
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_indexer(self, form, key, kind)
#    4747             pass
#    4748         elif kind in ["iloc", "getitem"]:
# -> 4749             self._invalid_indexer(form, key)
#    4750         return key
#    4751
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3074         """
#    3075         raise TypeError(
# -> 3076             f"cannot do {form} indexing on {type(self)} with these "
#    3077             f"indexers [{key}] of {type(key)}"
#    3078         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.numeric.Int64Index'> with these indexers [city_name] of <class 'str'>

# %%
df_newdata['city_top'] = df_city_sorted_imported['top']
df_newdata['city_name'] = df_city_sorted_imported['name']
df_newdata['city_index'] = df_city_sorted_imported['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-bc239ff73dd9> in <module>
#       1 df_newdata['city_top'] = df_city_sorted_imported['top']
#       2 df_newdata['city_name'] = df_city_sorted_imported['name']
# ----> 3 df_newdata['city_index'] = df_city_sorted_imported['index']
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'

# %%
df_newdata
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height  \
# index
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
#        city_top  diff   city_name
# index
# 0         266.0   0.0      London
# 1         309.0   0.0  Folkestone
# 2         339.0   1.0      London
# 3         370.0   0.0      London
# 4         400.0   1.0      Slough
# ...         ...   ...         ...
# 31314       NaN   NaN         NaN
# 31315       NaN   NaN         NaN
# 31316       NaN   NaN         NaN
# 31322       NaN   NaN         NaN
# 31323       NaN   NaN         NaN
#
# [31324 rows x 9 columns]

# %%
df_newdata['diff'] = df_newdata['top'] - df_newdata['city_top']

# %%
df_newdata['diff'] = df_newdata['diff'].abs()

# %%
df_newdata['diff']
# Out:
# index
# 0        0.0
# 1        0.0
# 2        1.0
# 3        0.0
# 4        1.0
#         ...
# 31314    NaN
# 31315    NaN
# 31316    NaN
# 31322    NaN
# 31323    NaN
# Name: diff, Length: 31324, dtype: float64

# %%
df_newdata_big_diff = df_newdata[df_newdata['diff'] > 1 ]

# %%
df_newdata.shape
# Out:
# (31324, 9)

# %%
df_newdata_big_diff.shape
# Out:
# (30294, 9)

# %%
df_newdata_big_diff
# Out:
#                                                    style  \
# index
# 28     position:absolute; border: textbox 1px solid; ...
# 29     position:absolute; border: textbox 1px solid; ...
# 30     position:absolute; border: textbox 1px solid; ...
# 31     position:absolute; border: textbox 1px solid; ...
# 32     position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31274  position:absolute; border: textbox 1px solid; ...
# 31278  position:absolute; border: textbox 1px solid; ...
# 31279  position:absolute; border: textbox 1px solid; ...
# 31275  position:absolute; border: textbox 1px solid; ...
# 31276  position:absolute; border: textbox 1px solid; ...
#
#                            name  left      top  width  height   city_top  \
# index
# 28           16HarleyCo Limited    30     1378     81       8     1408.0
# 29               16printing Ltd    30     1409     58       8     1439.0
# 30      17 Capital Services Ltd    30     1439     95       8     1469.0
# 31     18 Feet & Rising Limited    30     1470    101       8     1500.0
# 32           1854 Media Limited    30     1500     80       8     1531.0
# ...                         ...   ...      ...    ...     ...        ...
# 31274      Zion Capital Limited    30  1328466     83       8  1330318.0
# 31278     Zion Christian Church    30  1328496     91       8  1330465.0
# 31279               Zipcube ltd    30  1328539     46       8  1330495.0
# 31275           ZLC 7 Dials Ltd    30  1328600     63       8  1330348.0
# 31276        ZLC Energy Limited    30  1328631     82       8  1330391.0
#
#          diff          city_name
# index
# 28       30.0  Jewellery quarter
# 29       30.0             London
# 30       30.0             London
# 31       30.0             London
# 32       31.0             London
# ...       ...                ...
# 31274  1852.0           Hounslow
# 31278  1969.0             London
# 31279  1956.0             London
# 31275  1748.0          Lichfield
# 31276  1760.0    Blaydon on Tyne
#
# [30294 rows x 9 columns]

# %%
df_newdata_big_diff.index
# Out:
# Int64Index([   28,    29,    30,    31,    32,    27,    35,    36,    37,
#                38,
#             ...
#             31270, 31271, 31272, 31277, 31273, 31274, 31278, 31279, 31275,
#             31276],
#            dtype='int64', name='index', length=30294)

# %%
df_newdata_big_diff.index[0]
# Out:
# 28

# %%
df_newdata['top']
# Out:
# index
# 0            266
# 1            309
# 2            340
# 3            370
# 4            401
#           ...
# 31314    1330349
# 31315    1330392
# 31316    1330422
# 31322    1330465
# 31323    1330496
# Name: top, Length: 31324, dtype: int64
