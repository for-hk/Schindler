# %%
from lxml import html, etree
import requests
import pandas as pd

# %%
page = requests.get('https://www.gov.uk/government/publications/register-of-licensed-sponsors-workers')
tree = html.fromstring(page.content)

# %%
download_path = tree.xpath('//*[@id="attachment_4271537"]/div[2]/h2/a')[0].get("href")

# %%
print(download_path)
# Out:
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/891847/2020-06-12_Tier_2_5_Register_of_Sponsors.pdf

# %%
response = requests.get(download_path)

# %%
with open('/tmp/metadata.pdf', 'wb') as f:
    f.write(response.content)

# %%
# python3 pdf2txt.py metadata.pdf --output_type xml  --outfile raw.xml

# %%
# python3 pdf2txt.py metadata.pdf --output_type html  --outfile raw.html

# %%
# with open('./raw-sample.html', 'r') as f:
#     page = f.read()
# doc = html.fromstring(page)

# %%
with open('./raw_html_all.html', 'r') as f:
    page = f.read()
doc = html.fromstring(page)

# %%
doc.xpath('/html/body/div[7]')[0].text

# %% [markdown]
# ## Extract Organisation Name

# %%
name = []
city = []
country = []
tier_and_rating = []
sub_tier = []

isFirst = False

for col in doc.xpath("//div/span"):
    if ("left:30px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
            pairs = {'style': p_style, 'name': col.text.strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            name.append(pairs)
            isFirst = True
#             break

# %% [markdown]
# ## Extract Organisation Location

# %%
for col in doc.xpath("//div/span"):
    if ("left:357px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
            pairs = {'style': p_style, 'name': col.text.strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            city.append(pairs)
            isFirst = True
#             break

# %% [markdown]
# ## Extract Tier & Rating

# %%
tier_and_rating = []
for col in doc.xpath("//div/span"):
    if ("left:582px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
#             print(col.text_content().strip())
#             print(etree.tostring(col))
            pairs = {'style': p_style, 'name': col.text_content().strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            tier_and_rating.append(pairs)
            isFirst = True
#             break

# %% [markdown]
# ## Extract Sub Tier

# %%
sub_tier = []
for col in doc.xpath("//div/span"):
    if ("left:684px;" in col.getparent().get("style")):
        if isFirst or ("top:266px;" in col.getparent().get("style")):
            
            p_style = col.getparent().get("style")
#             print(col.text_content().strip())
#             print(etree.tostring(col))
            pairs = {'style': p_style, 'name': col.text_content().strip()}
            
            p_styles = p_style.split(';')
            for i in range(0, (len(p_styles)-1)):
                key_value = p_styles[i].split(':')
                if key_value[0].strip() in ['top', 'left', 'width', 'height']:
                    pairs[key_value[0].strip()] = int(key_value[1].replace('px','').strip())
#                 else:
#                     pairs[key_value[0].strip()] = key_value[1].replace('px','').strip()
            
#             print(pairs)
            sub_tier.append(pairs)
            isFirst = True
#             break

# %%
len(city)
# Out:
# 31280

# %%
name[101]
# Out:
# {'height': 8,
#  'left': 30,
#  'name': '3HR PLC',
#  'style': 'position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:30px; top:4246px; width:37px; height:8px;',
#  'top': 4246,
#  'width': 37}

# %%
df_name = pd.DataFrame(name)

# %%
df_name_sorted = df_name.sort_values(by=['top'])

# %%
df_name_sorted[0:]
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
# [31324 rows x 6 columns]

# %%
df_city = pd.DataFrame(city)

# %%
df_city_sorted = df_city.sort_values(by=['top'])

# %%
df_city_sorted[0:]
# Out:
#                                                    style             name  \
# 0      position:absolute; border: textbox 1px solid; ...           London
# 1      position:absolute; border: textbox 1px solid; ...       Folkestone
# 2      position:absolute; border: textbox 1px solid; ...           London
# 3      position:absolute; border: textbox 1px solid; ...           London
# 4      position:absolute; border: textbox 1px solid; ...           Slough
# ...                                                  ...              ...
# 31275  position:absolute; border: textbox 1px solid; ...        Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...  Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...        Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...           London
# 31279  position:absolute; border: textbox 1px solid; ...           London
#
#        left      top  width  height
# 0       357      266     29       8
# 1       357      309     43       8
# 2       357      339     29       8
# 3       357      370     29       8
# 4       357      400     27       8
# ...     ...      ...    ...     ...
# 31275   357  1330348     32       8
# 31276   357  1330391     67       8
# 31277   357  1330422     47       8
# 31278   357  1330465     29       8
# 31279   357  1330495     29       8
#
# [31280 rows x 6 columns]

# %%
df_sub_tier = pd.DataFrame(sub_tier)

# %%
df_sub_tier_sorted = df_sub_tier.sort_values(by=['top'])

# %%
df_sub_tier_sorted[0:]
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left      top  width  \
# 0                Tier 2 General\nCreative & Sporting   684      279     77
# 1                                Creative & Sporting   684      322     77
# 2                                     Tier 2 General   684      353     57
# 3                                     Tier 2 General   684      383     57
# 4                                     Tier 2 General   684      414     57
# ...                                              ...   ...      ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362    121
# 32584                                 Tier 2 General   684  1330405     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330435    121
# 32586                                 Tier 2 General   684  1330478     57
# 32587                                 Tier 2 General   684  1330509     57
#
#        height
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]

# %%
df_tier_and_rating = pd.DataFrame(tier_and_rating)

# %%
df_tier_and_rating_sorted = df_tier_and_rating.sort_values(by=['top'])

# %%
df_tier_and_rating_sorted
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32673  position:absolute; border: textbox 1px solid; ...
# 32674  position:absolute; border: textbox 1px solid; ...
# 32675  position:absolute; border: textbox 1px solid; ...
# 32676  position:absolute; border: textbox 1px solid; ...
# 32677  position:absolute; border: textbox 1px solid; ...
#
#                                        name  left      top  width  height
# 0      Tier 2 (A rating)\nTier 5 (A rating)   582      278     62      21
# 1                         Tier 5 (A rating)   582      321     62       8
# 2                         Tier 2 (A rating)   582      351     62       8
# 3                         Tier 2 (A rating)   582      382     62       8
# 4                         Tier 2 (A rating)   582      412     62       8
# ...                                     ...   ...      ...    ...     ...
# 32673  Tier 2 (A rating)\nTier 2 (A rating)   582  1330360     62      21
# 32674                     Tier 2 (A rating)   582  1330403     62       8
# 32675  Tier 2 (A rating)\nTier 2 (A rating)   582  1330434     62      21
# 32676                     Tier 2 (A rating)   582  1330477     62       8
# 32677                     Tier 2 (A rating)   582  1330507     62       8
#
# [32678 rows x 6 columns]

# %%
# for content in contents:
#     text_object = content.getObject()
#     print(text_object)

# %%
# with open("raw_text.csv", "w") as text_file:
#     text_file.write(all_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8f96918366a3> in <module>()
#       1 with open("raw_text.csv", "w") as text_file:
# ----> 2     text_file.write(all_text)
#
# NameError: name 'all_text' is not defined

# %%
# contents = pageObj.getContents()

# %% [markdown]
# ## Export dataframe to parquet

# %%
# pip install fastparquet ( if not already installed )

# %%
df_name_sorted.to_parquet('df_name_sorted.parquet.gzip',
              compression='gzip')

# %%
df_city_sorted.to_parquet('df_city_sorted.parquet.gzip',
              compression='gzip')

# %%
df_tier_and_rating_sorted.to_parquet('df_tier_and_rating_sorted.parquet.gzip',
              compression='gzip')

# %%
df_sub_tier_sorted.to_parquet('df_sub_tier_sorted.parquet.gzip',
              compression='gzip')

# %%
df_sub_tier_sorted
# Out:
#                                                    style  \
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left      top  width  \
# 0                Tier 2 General\nCreative & Sporting   684      279     77
# 1                                Creative & Sporting   684      322     77
# 2                                     Tier 2 General   684      353     57
# 3                                     Tier 2 General   684      383     57
# 4                                     Tier 2 General   684      414     57
# ...                                              ...   ...      ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362    121
# 32584                                 Tier 2 General   684  1330405     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330435    121
# 32586                                 Tier 2 General   684  1330478     57
# 32587                                 Tier 2 General   684  1330509     57
#
#        height
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]

# %% [markdown]
# ## Import dataframe from parquet

# %%
df_name_sorted_imported = pd.read_parquet('df_name_sorted.parquet.gzip')

# %%
df_name_sorted_imported[0:]
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 31314  position:absolute; border: textbox 1px solid; ...
# 31315  position:absolute; border: textbox 1px solid; ...
# 31316  position:absolute; border: textbox 1px solid; ...
# 31322  position:absolute; border: textbox 1px solid; ...
# 31323  position:absolute; border: textbox 1px solid; ...
#
#                                     name  left      top  width  height
# index
# 0      @ Home Accommodation Services Ltd    30      266    160       8
# 1               ]performance s p a c e [    30      309     98       8
# 2                               06472420    30      340     38       8
# 3                      0-two Maintenance    30      370     78       8
# 4              1 Digitals Europe Limited    30      401    105       8
# ...                                  ...   ...      ...    ...     ...
# 31314           Zytek Automotive Limited    30  1330349    106       8
# 31315          Zytronic Displays Limited    30  1330392    106       8
# 31316        ZyXEL Communications UK Ltd    30  1330422    131       8
# 31322                           ZZ&D LtD    30  1330465     40       8
# 31323                      Zzish Limited    30  1330496     55       8
#
# [31324 rows x 6 columns]

# %%
df_city_sorted_imported = pd.read_parquet('df_city_sorted.parquet.gzip')

# %%
df_city_sorted_imported
# Out:
#                                                    style             name  \
# index
# 0      position:absolute; border: textbox 1px solid; ...           London
# 1      position:absolute; border: textbox 1px solid; ...       Folkestone
# 2      position:absolute; border: textbox 1px solid; ...           London
# 3      position:absolute; border: textbox 1px solid; ...           London
# 4      position:absolute; border: textbox 1px solid; ...           Slough
# ...                                                  ...              ...
# 31275  position:absolute; border: textbox 1px solid; ...        Lichfield
# 31276  position:absolute; border: textbox 1px solid; ...  Blaydon on Tyne
# 31277  position:absolute; border: textbox 1px solid; ...        Wokingham
# 31278  position:absolute; border: textbox 1px solid; ...           London
# 31279  position:absolute; border: textbox 1px solid; ...           London
#
#        left      top  width  height
# index
# 0       357      266     29       8
# 1       357      309     43       8
# 2       357      339     29       8
# 3       357      370     29       8
# 4       357      400     27       8
# ...     ...      ...    ...     ...
# 31275   357  1330348     32       8
# 31276   357  1330391     67       8
# 31277   357  1330422     47       8
# 31278   357  1330465     29       8
# 31279   357  1330495     29       8
#
# [31280 rows x 6 columns]

# %%
df_tier_and_rating_sorted_imported = pd.read_parquet('df_tier_and_rating_sorted.parquet.gzip')

# %%
df_tier_and_rating_sorted_imported
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32673  position:absolute; border: textbox 1px solid; ...
# 32674  position:absolute; border: textbox 1px solid; ...
# 32675  position:absolute; border: textbox 1px solid; ...
# 32676  position:absolute; border: textbox 1px solid; ...
# 32677  position:absolute; border: textbox 1px solid; ...
#
#                                        name  left      top  width  height
# index
# 0      Tier 2 (A rating)\nTier 5 (A rating)   582      278     62      21
# 1                         Tier 5 (A rating)   582      321     62       8
# 2                         Tier 2 (A rating)   582      351     62       8
# 3                         Tier 2 (A rating)   582      382     62       8
# 4                         Tier 2 (A rating)   582      412     62       8
# ...                                     ...   ...      ...    ...     ...
# 32673  Tier 2 (A rating)\nTier 2 (A rating)   582  1330360     62      21
# 32674                     Tier 2 (A rating)   582  1330403     62       8
# 32675  Tier 2 (A rating)\nTier 2 (A rating)   582  1330434     62      21
# 32676                     Tier 2 (A rating)   582  1330477     62       8
# 32677                     Tier 2 (A rating)   582  1330507     62       8
#
# [32678 rows x 6 columns]

# %%
df_sub_tier_sorted_imported = pd.read_parquet('df_sub_tier_sorted.parquet.gzip')

# %%
df_sub_tier_sorted_imported
# Out:
#                                                    style  \
# index
# 0      position:absolute; border: textbox 1px solid; ...
# 1      position:absolute; border: textbox 1px solid; ...
# 2      position:absolute; border: textbox 1px solid; ...
# 3      position:absolute; border: textbox 1px solid; ...
# 4      position:absolute; border: textbox 1px solid; ...
# ...                                                  ...
# 32583  position:absolute; border: textbox 1px solid; ...
# 32584  position:absolute; border: textbox 1px solid; ...
# 32585  position:absolute; border: textbox 1px solid; ...
# 32586  position:absolute; border: textbox 1px solid; ...
# 32587  position:absolute; border: textbox 1px solid; ...
#
#                                                 name  left      top  width  \
# index
# 0                Tier 2 General\nCreative & Sporting   684      279     77
# 1                                Creative & Sporting   684      322     77
# 2                                     Tier 2 General   684      353     57
# 3                                     Tier 2 General   684      383     57
# 4                                     Tier 2 General   684      414     57
# ...                                              ...   ...      ...    ...
# 32583  Tier 2 General\nIntra Company Transfers (ICT)   684  1330362    121
# 32584                                 Tier 2 General   684  1330405     57
# 32585  Intra Company Transfers (ICT)\nTier 2 General   684  1330435    121
# 32586                                 Tier 2 General   684  1330478     57
# 32587                                 Tier 2 General   684  1330509     57
#
#        height
# index
# 0          21
# 1           8
# 2           8
# 3           8
# 4           8
# ...       ...
# 32583      21
# 32584       8
# 32585      21
# 32586       8
# 32587       8
#
# [32588 rows x 6 columns]
